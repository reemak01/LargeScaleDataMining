# %% [markdown]
# ### Module 2 - Twitter data

# %% [markdown]
# This is M2 of 3 modules for the twitter dataset. In this module, we cover the training parts to be used in M3 for prediction and inference for Q29. We extract the phrases, generate entities and finally create the dataset used for prediction.

# %%
import numpy as np
import random
import pandas as pd
import orjson as json
import time
from datetime import datetime

import regex as re
import spacy
import pytextrank
import multiprocessing as mp
from multiprocessing import Pool
import pickle
from fuzzywuzzy import fuzz

from nltk.corpus import stopwords
stopwords = stopwords.words('english')

num_cores = 4 #number of cores on your machine
num_partitions = 16 #number of partitions to split dataframe

nlp = spacy.load("en_core_web_sm")
nlp.add_pipe("textrank")

# %%
## Load data
start_time = time.time()
files_tag = ['gohawks', 'gopatriots', 'nfl', 'patriots', 'sb49', 'superbowl']

df = pd.DataFrame()
tweet_id_ls = []
file_tag_ls = []
tweet_text_ls = []
tweet_time_ls = []

for file in files_tag:
    myJSON = []
    print("Reading file : "+file)
    for line in open('./data/ECE219_tweet_data/tweets_#'+file+'.txt','r'):
        data = json.loads(line)
        tweet_id_ls.append(data['tweet']['id_str'])
        file_tag_ls.append(file)
        tweet_text_ls.append(data['tweet']['text'])
        tweet_time_ls.append(data['citation_date'])

tweet_txt = pd.DataFrame({'tweet_id': tweet_id_ls, 'file': file_tag_ls,\
                          'text': tweet_text_ls, 'citation_datetime': tweet_time_ls})

print("done in %0.3fs." % (time.time() - start_time))
# Out:
# Reading file : gohawks
# Reading file : gopatriots
# Reading file : nfl
# Reading file : patriots
# Reading file : sb49
# Reading file : superbowl
# done in 90.407s.

# %%
def clean(text):
    '''
    Helps remove many HTML artefacts from the crawler's output.
    '''
    text = re.sub(r'^https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)
    text = re.sub(r'^http?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)
    texter = re.sub(r"<br />", " ", text)
    texter = re.sub(r"&quot;", "\"",texter)
    texter = re.sub('&#39;', "\"", texter)
    texter = re.sub('\n', " ", texter)
    texter = re.sub(' u '," you ", texter)
    texter = re.sub('`',"", texter)
    texter = re.sub(' +', ' ', texter)
    texter = re.sub(r"(!)\1+", r"!", texter)
    texter = re.sub(r"(\?)\1+", r"?", texter)
    texter = re.sub('&amp;', 'and', texter)
    texter = re.sub('\r', ' ',texter)
    clean = re.compile('<.*?>')
    texter = texter.encode('ascii', 'ignore').decode('ascii')
    texter = re.sub(clean, '', texter)
    if texter == "":
        texter = ""
    return texter

def text_preprocessing (text: str):
    text = text.lower()
    text = clean(text)
    return text

# %% [markdown]
# ### Phrase extraction

# %% [markdown]
# In this part, we extract top 3 phrases from each tweet text using text rank after applying basic text cleaning

# %%
start_time = time.time()
print("Pre-processing tweet text for phrase extraction..")
tweet_txt['clean_text'] = tweet_txt['text'].apply(lambda x: text_preprocessing(x))
print("done in %0.3fs." % (time.time() - start_time))
# Out:
# Pre-processing tweet text for phrase extraction..
# done in 108.820s.

# %%
def get_phrases (text: str, tweet_id : str, top_n = 3):
    '''
    Given a tweet id and text, returns top 3 phrases
    '''
    try:
        doc = nlp(text)
        phrases_dict = {}
        for phrase in doc._.phrases:
            phrases_dict[(tweet_id, phrase.text)] = phrase.rank

        a = dict(sorted(phrases_dict.items(), key=lambda x: x[1], reverse=True)[:top_n])
        return a

           
    except:
        print('Error for Tweet ID %s' % tweet_id)

# %%
phrase_extraction_df = tweet_txt[['tweet_id', 'clean_text']].drop_duplicates()

# %%
start_time = time.time()
final_dict = {}
for index, row in phrase_extraction_df.iterrows():
    tmp_dict = get_phrases(row['clean_text'], row['tweet_id'])
    final_dict.update(tmp_dict)
    if(index % 10000 == 0):
        print(index)
        print("done in %0.3fs." % (time.time() - start_time)) 
        output = open('./twitter_files_v3/textrank_phrases_v2.pkl', 'wb')
        pickle.dump(final_dict, output)
# Out:
# 0
# done in 0.017s.
# 10000
# done in 64.451s.
# 20000
# done in 126.352s.
# 30000
# done in 185.181s.
# 40000
# done in 242.352s.
# 50000
# done in 297.662s.
# 60000
# done in 355.376s.
# 70000
# done in 417.387s.
# 80000
# done in 480.085s.
# 90000
# done in 545.729s.
# 100000
# done in 612.380s.
# 110000
# done in 673.488s.
# 120000
# done in 738.426s.
# 130000
# done in 797.466s.
# 140000
# done in 853.193s.
# 150000
# done in 910.946s.
# 160000
# done in 967.202s.
# 170000
# done in 1030.363s.
# 180000
# done in 1086.957s.
# 190000
# done in 1143.337s.
# 200000
# done in 1209.398s.
# 210000
# done in 1270.400s.
# 220000
# done in 1330.391s.
# 230000
# done in 1397.330s.
# 240000
# done in 1462.670s.
# 260000
# done in 1593.722s.
# 270000
# done in 1663.351s.
# 280000
# done in 1732.864s.
# 290000
# done in 1800.887s.
# 300000
# done in 1867.445s.
# 310000
# done in 1933.838s.
# 320000
# done in 1995.052s.
# 330000
# done in 2056.889s.
# 340000
# done in 2120.953s.
# 350000
# done in 2177.911s.
# 360000
# done in 2234.914s.
# 370000
# done in 2303.198s.
# 380000
# done in 2371.161s.
# 390000
# done in 2436.136s.
# 400000
# done in 2504.851s.
# 410000
# done in 2575.747s.
# 420000
# done in 2645.278s.
# 430000
# done in 2711.782s.
# 440000
# done in 2766.443s.
# 450000
# done in 2820.565s.
# 460000
# done in 2876.970s.
# 470000
# done in 2935.988s.
# 480000
# done in 2995.249s.
# 490000
# done in 3052.290s.
# 500000
# done in 3107.420s.
# 520000
# done in 3215.015s.
# 530000
# done in 3276.413s.
# 540000
# done in 3331.600s.
# 570000
# done in 3496.985s.
# 580000
# done in 3557.966s.
# 590000
# done in 3615.495s.
# 600000
# done in 3674.810s.
# 610000
# done in 3732.412s.
# 620000
# done in 3793.518s.
# 630000
# done in 3856.560s.
# 640000
# done in 3915.215s.
# 650000
# done in 3974.157s.
# 660000
# done in 4033.448s.
# 670000
# done in 4092.393s.
# 680000
# done in 4161.042s.
# 690000
# done in 4225.956s.
# 700000
# done in 4287.820s.
# 710000
# done in 4346.565s.
# 720000
# done in 4404.291s.
# 730000
# done in 4460.222s.
# 740000
# done in 4515.912s.
# 750000
# done in 4572.970s.
# 760000
# done in 4631.493s.
# 770000
# done in 4687.956s.
# 780000
# done in 4746.241s.
# 790000
# done in 4803.745s.
# 800000
# done in 4863.144s.
# 810000
# done in 4919.728s.
# 820000
# done in 4975.558s.
# 830000
# done in 5033.518s.
# 840000
# done in 5093.014s.
# 860000
# done in 5212.036s.
# 880000
# done in 5289.415s.
# 890000
# done in 5346.671s.
# 900000
# done in 5399.848s.
# 930000
# done in 5525.446s.
# 940000
# done in 5562.568s.
# 950000
# done in 5595.373s.
# 960000
# done in 5629.869s.
# 980000
# done in 5694.224s.
# 990000
# done in 5734.029s.
# 1000000
# done in 5769.850s.
# 1050000
# done in 5928.592s.
# 1060000
# done in 5967.938s.
# 1070000
# done in 6004.553s.
# 1100000
# done in 6111.756s.
# 1130000
# done in 6217.205s.
# 1150000
# done in 6291.637s.
# 1160000
# done in 6330.958s.
# 1170000
# done in 6369.586s.
# 1190000
# done in 6447.404s.
# 1200000
# done in 6488.045s.
# 1210000
# done in 6530.071s.
# 1220000
# done in 6572.270s.
# 1230000
# done in 6614.303s.
# 1250000
# done in 6695.340s.
# 1260000
# done in 6740.220s.
# 1280000
# done in 6833.359s.
# 1290000
# done in 6883.797s.
# 1300000
# done in 6936.120s.
# 1310000
# done in 6985.471s.
# 1320000
# done in 7030.237s.
# 1330000
# done in 7084.032s.
# 1340000
# done in 7141.723s.
# 1350000
# done in 7196.962s.
# 1360000
# done in 7251.676s.
# 1370000
# done in 7310.394s.
# 1380000
# done in 7370.337s.
# 1390000
# done in 7429.763s.
# 1400000
# done in 7487.143s.
# 1410000
# done in 7541.216s.
# 1420000
# done in 7600.253s.
# 1430000
# done in 7661.769s.
# 1440000
# done in 7725.633s.
# 1450000
# done in 7786.819s.
# 1460000
# done in 7850.262s.
# 1470000
# done in 7913.530s.
# 1480000
# done in 7977.186s.
# 1490000
# done in 8035.381s.
# 1500000
# done in 8099.043s.
# 1510000
# done in 8164.431s.
# 1520000
# done in 8222.192s.
# 1530000
# done in 8288.574s.
# 1540000
# done in 8344.096s.
# 1550000
# done in 8387.108s.
# 1560000
# done in 8440.458s.
# 1570000
# done in 8503.608s.
# 1590000
# done in 8629.986s.
# 1600000
# done in 8697.305s.
# 1620000
# done in 8810.577s.
# 1630000
# done in 8859.051s.
# 1640000
# done in 8898.234s.
# 1660000
# done in 9009.144s.
# 1670000
# done in 9055.897s.
# 1680000
# done in 9101.551s.
# 1690000
# done in 9154.840s.
# 1700000
# done in 9209.974s.
# 1730000
# done in 9372.356s.
# 1740000
# done in 9434.537s.
# 1750000
# done in 9497.481s.
# 1770000
# done in 9619.421s.
# 1780000
# done in 9676.907s.
# 1790000
# done in 9736.276s.
# 1810000
# done in 9845.495s.
# 1820000
# done in 9895.569s.
# 1840000
# done in 9971.696s.
# 1850000
# done in 10012.082s.
# 1860000
# done in 10052.124s.
# 1880000
# done in 10130.525s.
# 1900000
# done in 10218.370s.
# 1910000
# done in 10264.773s.
# 1940000
# done in 10408.055s.
# 1950000
# done in 10463.427s.
# 1960000
# done in 10520.800s.
# 1970000
# done in 10584.147s.
# 1980000
# done in 10635.723s.
# 1990000
# done in 10690.679s.
# 2010000
# done in 10801.383s.
# 2020000
# done in 10860.365s.
# 2030000
# done in 10920.628s.
# 2040000
# done in 10978.083s.
# 2050000
# done in 11038.027s.
# 2060000
# done in 11097.217s.
# 2070000
# done in 11158.794s.
# 2080000
# done in 11223.267s.
# 2090000
# done in 11281.170s.
# 2100000
# done in 11334.346s.
# 2110000
# done in 11388.770s.
# 2120000
# done in 11447.878s.
# 2130000
# done in 11510.653s.
# 2140000
# done in 11574.282s.
# 2150000
# done in 11639.821s.
# 2160000
# done in 11701.603s.
# 2180000
# done in 11817.971s.
# 2190000
# done in 11880.810s.
# 2200000
# done in 11938.516s.
# 2230000
# done in 12099.437s.
# 2240000
# done in 12160.278s.
# 2250000
# done in 12219.978s.
# 2260000
# done in 12279.784s.
# 2270000
# done in 12343.532s.
# 2280000
# done in 12404.881s.
# 2290000
# done in 12469.115s.
# 2300000
# done in 12532.348s.
# 2310000
# done in 12598.512s.
# 2320000
# done in 12667.642s.
# 2340000
# done in 12777.876s.
# 2350000
# done in 12836.802s.
# 2360000
# done in 12900.079s.
# 2370000
# done in 12967.933s.
# 2380000
# done in 13032.472s.
# 2400000
# done in 13159.502s.
# 2410000
# done in 13225.826s.
# 2420000
# done in 13287.884s.
# 2430000
# done in 13347.697s.
# 2440000
# done in 13402.549s.
# 2450000
# done in 13460.242s.
# 2460000
# done in 13519.036s.
# 2470000
# done in 13573.261s.
# 2480000
# done in 13628.122s.
# 2490000
# done in 13686.526s.
# 2500000
# done in 13746.792s.
# 2520000
# done in 13869.771s.
# 2530000
# done in 13935.383s.
# 2540000
# done in 13998.281s.
# 2560000
# done in 14122.376s.
# 2580000
# done in 14240.396s.
# 2590000
# done in 14296.898s.
# 2600000
# done in 14350.306s.
# 2610000
# done in 14401.051s.
# 2630000
# done in 14493.711s.
# 2640000
# done in 14545.149s.
# 2650000
# done in 14595.432s.
# 2670000
# done in 14688.160s.
# 2680000
# done in 14737.003s.
# 2690000
# done in 14789.147s.
# 2720000
# done in 14958.236s.
# 2730000
# done in 15006.242s.
# 2750000
# done in 15081.477s.
# 2760000
# done in 15140.457s.
# 2780000
# done in 15255.788s.
# 2790000
# done in 15315.859s.
# 2800000
# done in 15377.407s.
# 2810000
# done in 15436.360s.
# 2820000
# done in 15497.447s.

# %%
output = open('./twitter_files_v3/textrank_phrases_v2.pkl', 'wb')
pickle.dump(final_dict, output)

# %% [markdown]
# ### Phrase post-processing

# %% [markdown]
# In this part, we process the extracted phrases and do some cleaning on extracted phrases for subsequent tasks

# %%
txtrank_phrase_file = open('./twitter_files_v3/textrank_phrases_v2.pkl', "rb")
txtrank_phrases = pickle.load(txtrank_phrase_file)

# %%
#### Drop if all numeric
def all_numeric(number_sequence: str):
     return all(var.isdigit() for var in number_sequence.split())

def drop_allNumeric (data):
    data['allNumeric'] = data['clean_phrase'].apply(lambda x: all_numeric(str(x)))
    data = data[data['allNumeric'] == False]
    data = data.drop(['allNumeric'], axis=1)
    return data

# %%
def clean(text: str):
    
    # remove punctuation
    text = re.sub('[!"#$%&()*+-/:;<=>?@[\\]^_`{|}~]', '', text)
    
    # remove the from beginning
    if (text.startswith("the")):
        text = text.replace("the", '', 1)
        
    # remove http tokens
    tokens = text.split(' ')
    tokens_filt = [i for i in tokens if not i.startswith('http')]
    text = ' '.join(tokens_filt)
    
    # remove trailing spaces
    text = text.rstrip()
    text = text.lstrip()
    
    return text

def remove_stopwords(data):
    phrase_counts = data.groupby(['clean_phrase']).size().reset_index(name = 'count')
    phrase_counts = phrase_counts.sort_values('count', ascending = False)
    phrase_counts['len'] = phrase_counts['clean_phrase'].apply(lambda x: len(x.split(' ')))
    phrase_counts['single_stopword_tag'] = phrase_counts.apply(lambda row: int(row['clean_phrase'] in stopwords) \
                                                         if (row['len'] == 1) else 0, axis = 1)
    data = pd.merge(data, phrase_counts[['clean_phrase', 'single_stopword_tag']], how = 'left', on = 'clean_phrase')
    data = data[data['single_stopword_tag'] == 0]
    data = data.drop(['single_stopword_tag'], axis = 1)
    return data
    

def clean_phrases (txtrank_phrases):
    '''
    Given the dictionary of textrank, tweet phrases; clean the phrases to get better entities.
    Returns a dataframe `txtrank_dt` with columns - tweet_id, ranking score, phrase and other tweet info
    '''
    
    ## Read phrases
    txtrank_df = pd.DataFrame.from_dict(txtrank_phrases, orient = 'index').reset_index()
    txtrank_df[['tweet_id', 'phrase']] = pd.DataFrame(txtrank_df['index'].tolist(),\
                                                  index=txtrank_df.index)
    txtrank_df = txtrank_df.drop_duplicates()
    
    ## clean phrase
    txtrank_df['clean_phrase'] = txtrank_df['phrase'].apply(lambda x: clean(x))
    
    ##drop single word stopword phrases
    txtrank_df = remove_stopwords(txtrank_df)
    
    ## remove if length of phrase < 2
    txtrank_df['len'] = txtrank_df['clean_phrase'].apply(lambda x: len(x))
    txtrank_df = txtrank_df[txtrank_df['len'] > 2]
    txtrank_df = txtrank_df.drop(['len'], axis=1)
    
    ## get count of phrases and drop if count == 1
    phrase_counts = txtrank_df.groupby(['clean_phrase']).size().reset_index(name = 'count')
    phrase_counts = phrase_counts.sort_values('count', ascending = False)
    txtrank_df = pd.merge(txtrank_df, phrase_counts, how = 'left', on = 'clean_phrase')
    txtrank_df = txtrank_df[txtrank_df['count'] > 1]
    txtrank_df = txtrank_df.drop(['count'], axis=1)
    
    return txtrank_df

# %%
start_time = time.time()
print("Post-processing extracted phrases...")
txtrank_df = clean_phrases(txtrank_phrases)
txtrank_df = drop_allNumeric(txtrank_df)
print("done in %0.3fs." % (time.time() - start_time))
# Out:
# Post-processing extracted phrases...
# done in 76.439s.

# %% [markdown]
# ### Entity extraction

# %% [markdown]
# In this part, we process the phrases to determine whether they are a valid entity

# %%
def get_phrase_counts_overall (txtrank_df):
    '''
    Given the text rank dataframe with clean tweet phrases; get the frequency of how many times a phrase was 
    used in the entire tweet dataset to assess popular phrases/entities.
    Returns a dataframe `phrase_counts` with columns - `clean_phrase` (the phrase) and `count` (num of occurences)
    '''
    
    phrase_counts = txtrank_df.groupby(['clean_phrase']).size().reset_index(name = 'count')
    phrase_counts = phrase_counts.sort_values('count', ascending = False)
    
    return phrase_counts

def get_close_entities(allphrases : list, entity : str, threshold = 10):
    '''
    Given a phrase, map other phrases to this phrase using fuzzy text matching
    '''
    close_entities = []
    for phrase in allphrases:
        val = fuzz.ratio(phrase, entity)
        if(val > 85):
            close_entities.append(phrase)
    
    if(len(close_entities) > threshold):
        return close_entities
    else:
        return "Not an entity"

# %%
phrase_counts = get_phrase_counts_overall(txtrank_df)
phrase_counts = phrase_counts.sort_values('count', ascending = False)
phrase_counts['entity'] = 'NA'

# %%
phrase_counts.head()
# Out:
#          clean_phrase   count entity
# 154665           sb49  528347     NA
# 173591      superbowl  318933     NA
# 123949            nfl  235215     NA
# 176634  superbowlxlix  185221     NA
# 136621       patriots  176941     NA

# %%
start_time = time.time()

tmp = phrase_counts[phrase_counts['count'] > 20]
tmp = tmp.sort_values('count', ascending = False)
prospect_entities = list(tmp['clean_phrase'])

entity_dict = {}
entity_key = 1
counter = 0
ind = 0
for phrase in prospect_entities:
    counter +=1
    if(counter % 1000 == 0):
        counter = 0
        ind += 1
        print("Completed for: ", ind)
        print("done in %0.3fs." % (time.time() - start_time)) 
        
    entity_val = list(phrase_counts[phrase_counts['clean_phrase'] == phrase]['entity'])[0]
    
    if(entity_val == 'NA'):
        allphrases = list(phrase_counts[phrase_counts['entity'] == 'NA']['clean_phrase'])
        close_entities = get_close_entities(allphrases, phrase)
        if(close_entities == 'Not an entity'):
            phrase_counts.loc[ (phrase_counts['clean_phrase'] == phrase), 'entity'] = 'Not an entity'
        else:
            phrase_counts.loc[ (phrase_counts['clean_phrase'].isin(close_entities)), 'entity'] = phrase
            entity_dict[entity_key] = phrase
            entity_key = entity_key+1
# Out:
# Completed for:  1
# done in 518.509s.
# Completed for:  2
# done in 1021.617s.
# Completed for:  3
# done in 1576.296s.
# Completed for:  4
# done in 2119.950s.
# Completed for:  5
# done in 2653.637s.
# Completed for:  6
# done in 3188.805s.
# Completed for:  7
# done in 3717.095s.
# Completed for:  8
# done in 4245.117s.
# Completed for:  9
# done in 4768.835s.
# Completed for:  10
# done in 5289.821s.
# Completed for:  11
# done in 5802.139s.
# Completed for:  12
# done in 6289.340s.
# Completed for:  13
# done in 6772.206s.
# Completed for:  14
# done in 7280.914s.

# %%
output = open('./twitter_files_v3/entities_v2.pkl', 'wb')
pickle.dump(entity_dict, output)
output.close()

# %%
output = open('./twitter_files_v3/clean_phrase_to_entity_v2.pkl', 'wb')
pickle.dump(phrase_counts, output)
output.close()

# %% [markdown]
# ### Get data for prediction tasks

# %%
data = pd.merge(txtrank_df, phrase_counts, how = 'left', on = 'clean_phrase')
## merge tweet text and time
data = pd.merge(data, tweet_txt, how = 'left', on = 'tweet_id')
output = open('./twitter_files_v3/prediction_data_v2.pkl', 'wb')
pickle.dump(data, output)
output.close()

# %%
entity_dict
# Out:
# {1: 'superbowl',
#  2: 'superbowlxlix',
#  3: 'patriots',
#  4: 'seahawks',
#  5: 'gohawks',
#  6: 'patriotswin nfl',
#  7: 'katyperry',
#  8: 'tom brady',
#  9: 'seattle',
#  10: 'halftime',
#  11: 'football',
#  12: 'pats',
#  13: 'superbowlcommercials',
#  14: 'gopats',
#  15: 'superbowlsunday',
#  16: 'seattleseahawks',
#  17: 'touchdown',
#  18: 'commercials',
#  19: 'new england',
#  20: 'superbowl2015',
#  21: 'marshawn lynch',
#  22: 'katy',
#  23: 'patsnation',
#  24: 'new england patriots',
#  25: 'missyelliott',
#  26: 'budweiser',
#  27: 'this game',
#  28: 'sb49 superbowl',
#  29: 'patriotsnation',
#  30: 'russell wilson',
#  31: 'katyperry superbowl',
#  32: 'packers',
#  33: 'wilson',
#  34: 'people',
#  35: 'halftime show',
#  36: 'pete carroll',
#  37: 'america',
#  38: 'chris matthews',
#  39: 'beastmode',
#  40: 'dangerusswilson',
#  41: 'allyouneedisecuador',
#  42: 'nflplayoffs',
#  43: 'lenny kravitz',
#  44: 'bill belichick',
#  45: 'last year',
#  46: 'next year',
#  47: 'los',
#  48: 'tom',
#  49: 'national anthem',
#  50: 'belichick',
#  51: 'interception',
#  52: 'edelman',
#  53: 'seahawkswin',
#  54: 'our 2015 super bowl commercial',
#  55: 'this superbowl',
#  56: 'man',
#  57: 'seahawks superbowl',
#  58: 'gohawks sb49',
#  59: 'richard sherman',
#  60: 'sports',
#  61: 'a game',
#  62: 'mcdonalds',
#  63: 'win',
#  64: 'afcchampionship',
#  65: 'day',
#  66: 'idinamenzel',
#  67: 'john legend',
#  68: 'defense',
#  69: 'champions',
#  70: 'touchdown patriots',
#  71: 'malcolm butler',
#  72: 'sherman',
#  73: 'superbowl halftime show',
#  74: 'deflategate',
#  75: 'great game',
#  76: 'matthews',
#  77: 'nationwide',
#  78: 'liam neeson',
#  79: 'seahawks fans',
#  80: 'nfl superbowl',
#  81: 'greenbay',
#  82: 'patriotsvsseahawks',
#  83: 'espntemsuperbowl49',
#  84: 'superbowl ads',
#  85: 'robgronkowski',
#  86: 'things',
#  87: 'touchdown seahawks',
#  88: 'sea',
#  89: 'patriots fans',
#  90: 'deflated balls',
#  91: 'julian edelman',
#  92: 'congratulations',
#  93: 'seahawks sb49',
#  94: 'halftimeshowkatyperry',
#  95: 'los patriots',
#  96: 'lol superbowl',
#  97: 'robert kraft',
#  98: 'sb49 seahawks',
#  99: 'patriotsvscolts',
#  100: 'american football',
#  101: 'superbowlxlix superbowl',
#  102: 'hahaha',
#  103: 'sb49 patriots',
#  104: 'this halftime show',
#  105: 'indianapolis colts',
#  106: 'katyperry sb49',
#  107: 'dancing sharks',
#  108: 'roger goodell',
#  109: 'superbowl history',
#  110: 'seahawksvspackers',
#  111: 'fantasyfootball',
#  112: 'superbowl time',
#  113: 'jeremy lane',
#  114: 'best superbowl',
#  115: 'football superbowl',
#  116: '4th quarter',
#  117: 'superbowl weekend',
#  118: 'kim kardashian',
#  119: 'los seahawks',
#  120: 'de katy',
#  121: 'some football',
#  122: 'walter white',
#  123: 'happy superbowl',
#  124: 'del superbowl',
#  125: 'men',
#  126: 'el partido',
#  127: 'best commercial',
#  128: 'patriots superbowl',
#  129: 'your superbowl party',
#  130: 'sb49 commercials',
#  131: 'quarterback',
#  132: 'domestic violence',
#  133: 'halftime superbowl',
#  134: 'my patriots',
#  135: 'afc title game',
#  136: 'peyton manning',
#  137: 'best halftime show',
#  138: 'superbowlsunday superbowlxlix',
#  139: 'bittersweet symphony',
#  140: 'katie perry',
#  141: 'a football game',
#  142: 'kim jong un',
#  143: 'superbowlbound',
#  144: 'that commercial',
#  145: 'seahawks gohawks',
#  146: 'nationwide commercial',
#  147: 'budweiser commercial',
#  148: 'aaron rodgers',
#  149: 'sb49 halftime show',
#  150: 'that interception',
#  151: 'raiders',
#  152: 'green bay packers',
#  153: 'sb49 nfl',
#  154: 'superbowl katyperry',
#  155: 'patriotsnation patriots',
#  156: 'a wardrobe malfunction',
#  157: 'super bowl party',
#  158: 'britneyspears',
#  159: 'el sb49',
#  160: 'andrew luck',
#  161: 'beastmode superbowlxlix',
#  162: 'patriots sb49',
#  163: 'super bowl champs',
#  164: 'katy perrys halftime show',
#  165: 'superbowl2015 superbowl',
#  166: 'halftimeshow superbowlxlix',
#  167: 'seattleseahawks superbowl',
#  168: 'afc championship game',
#  169: 'superbowl patriots',
#  170: 'points',
#  171: 'chris collinsworth',
#  172: 'brandon lafell',
#  173: 'superbowl spot',
#  174: 'gohawks 12thman',
#  175: 'patriots defense',
#  176: 'last minute',
#  177: 'game superbowl',
#  178: 'action',
#  179: 'patriots game',
#  180: 'int',
#  181: 'gohawks seahawks',
#  182: 'nfl football',
#  183: 'number',
#  184: 'katyperry lennykravitz',
#  185: 'san francisco 49ers',
#  186: 'seahawks defense',
#  187: 'game balls',
#  188: 'seahawks game',
#  189: 'paul mccartney',
#  190: 'missyelliott superbowl',
#  191: 'this shit',
#  192: 'michael bennett',
#  193: 'sb49 patsnation',
#  194: 'patriotsnation superbowlxlix',
#  195: 'my seahawks',
#  196: 'katyperry halftime',
#  197: 'chris pratt',
#  198: 'a firework',
#  199: 'nfl players',
#  200: 'legarrette blount',
#  201: 'vince wilfork',
#  202: 'seahawksvspatriots',
#  203: 'chicken wings',
#  204: 'woohoo',
#  205: 'patriots patriots',
#  206: 'bandwagon',
#  207: 'patriots win',
#  208: 'katy perrys performance',
#  209: 'field goal',
#  210: 'tombrady superbowl',
#  211: 'sore losers',
#  212: 'nfl patriots',
#  213: 'jurassicworld',
#  214: 'best superbowl commercial',
#  215: 'world champions',
#  216: 'this patriots',
#  217: 'katyperry katyperrysuperbowl',
#  218: 'captain america',
#  219: 'nationwide superbowl',
#  220: 'philadelphia eagles',
#  221: '2 minutes',
#  222: 'funny commercials',
#  223: 'nfl investigation',
#  224: 'katy perry concert',
#  225: 'great superbowl',
#  226: 'nevssea superbowlxlix',
#  227: 'that touchdown',
#  228: 'patriots balls',
#  229: 'viendo el superbowl',
#  230: 'touchdown superbowl',
#  231: 'scottsdale',
#  232: '1 yard line',
#  233: 'amazing superbowl',
#  234: 'halftimeshowkatyperry superbowl',
#  235: 'old people',
#  236: 'another superbowl',
#  237: 'superbowi sb49',
#  238: 'football fans',
#  239: 'superbowlcommercials superbowl',
#  240: 'super bowl mvp',
#  241: 'another touchdown',
#  242: 'nfl seahawks',
#  243: 'nissan commercial',
#  244: 'del medio tiempo',
#  245: 'a thing',
#  246: 'my favorite part',
#  247: 'vamos patriots',
#  248: 'seahawks nfl',
#  249: 'your favorite superbowl commercial',
#  250: 'this years superbowl',
#  251: 'good commercials',
#  252: 'seattle superbowl',
#  253: 'los comerciales',
#  254: 'your superbowl',
#  255: 'football season',
#  256: 'performance',
#  257: 'superbowl baby',
#  258: 'likeagirl commercial',
#  259: 'boo',
#  260: 'mvp superbowl',
#  261: 'superbowl xlix win',
#  262: 'my prediction',
#  263: 'el entretiempo',
#  264: 'dodge commercial',
#  265: 'seahawks dangerusswilson',
#  266: 'seconds',
#  267: 'touchdown baby',
#  268: 'a great day',
#  269: 'nfl super bowl xlix',
#  270: 'superbowl snacks',
#  271: 'awesome superbowl',
#  272: 'brady patriots',
#  273: 'katy perry time',
#  274: 'that ad',
#  275: 'bradys balls',
#  276: 'patsnation superbowl',
#  277: 'superbowlxlix seahawks',
#  278: 'con',
#  279: 'td patriots',
#  280: 'offensive coordinator',
#  281: 'el espectculo',
#  282: 'el show de medio tiempo',
#  283: 'seahawks 12thman',
#  284: 'lego',
#  285: 'nfl season',
#  286: 'superbowl win',
#  287: 'a ball',
#  288: 'depressing commercials',
#  289: 'a shit',
#  290: 'my friends',
#  291: 'patriots baby',
#  292: '30 seconds',
#  293: 'superbowlxlix champions',
#  294: 'dad commercials',
#  295: '30 minutes',
#  296: 'seahawks touchdown',
#  297: 'first superbowl',
#  298: 'weight watchers',
#  299: 'commercial break',
#  300: 'woo',
#  301: 'brady superbowlxlix',
#  302: 'that chevy commercial',
#  303: 'todays superbowl',
#  304: 'football players',
#  305: 'halftime performance',
#  306: 'seahawks lets',
#  307: '2015 superbowl',
#  308: 'nation',
#  309: 'tonights superbowl',
#  310: 'defensive player',
#  311: 'gopats superbowl',
#  312: 'super bowl tickets',
#  313: 'vamos seahawks',
#  314: 'katyperry missyelliott',
#  315: 'more commercials',
#  316: 'our seahawks',
#  317: 'td seahawks',
#  318: 'press conference',
#  319: 'para el superbowl',
#  320: 'superbowl night',
#  321: 'jajajaja',
#  322: 'budweiser puppy',
#  323: 'all these commercials',
#  324: 'doritos commercial',
#  325: 'wooooo',
#  326: '4 hours',
#  327: 'missy superbowl',
#  328: 'lol gohawks',
#  329: 'deflategate patriots',
#  330: 'cheerleaders',
#  331: 'se superbowlxlix commercials',
#  332: 'les',
#  333: 'hahahahaha',
#  334: 'bus',
#  335: '15 minutes',
#  336: 'esperando',
#  337: 'good superbowl',
#  338: 'california girls',
#  339: 'idinamenzel superbowl',
#  340: 'this seahawks',
#  341: 'best superbowlxlix tickets',
#  342: 'xlix superbowl',
#  343: 'superbowl football',
#  344: 'el espectculo de medio',
#  345: 'my favorite commercial',
#  346: 'a time',
#  347: 'katyperry superbowl halftime show',
#  348: 'jurassic world trailer',
#  349: 'happy birthday',
#  350: 'superbowlxlix superbowlcommercials',
#  351: 'that superbowlxlix',
#  352: 'nfl nfl',
#  353: 'seahawks seattle',
#  354: 'seattle seahawks fans',
#  355: 'an amazing game',
#  356: 'est',
#  357: 'gronk superbowl',
#  358: 'great commercial',
#  359: 'a katy perry wardrobe malfunction',
#  360: 'cocacola commercial',
#  361: 'foxsports',
#  362: 'domingo de superbowl',
#  363: 'superbowl food',
#  364: 'clans commercial',
#  365: 'seahawks score',
#  366: 'dis',
#  367: 'soooooo',
#  368: 'darrell bevell',
#  369: 'so far superbowl',
#  370: 'mas',
#  371: 'superbowl tweets',
#  372: 'patriots haters',
#  373: 'last years superbowl',
#  374: 'patriots players',
#  375: 'a katy',
#  376: 'great show',
#  377: 'this superbowl party',
#  378: 'patriots patriotsnation',
#  379: 'crazy superbowl',
#  380: 'commercial superbowl',
#  381: 'superbowl prediction',
#  382: 'seahawks baby',
#  383: 'katyperry katyperry',
#  384: 'katy perrys boobs',
#  385: 'seahawks seahawks',
#  386: 'mcdonalds commercial',
#  387: 'sunday superbowl',
#  388: 'seahawks gear',
#  389: 'packers fans',
#  390: 'new england superbowl',
#  391: 'quiera el superbowlxlix',
#  392: 'seahawks football',
#  393: 'a superbowlxlix party',
#  394: 'seahawks 12s',
#  395: 'superbowlxlix halftime',
#  396: 'movie trailers',
#  397: 'a superbowl game',
#  398: 'every superbowl',
#  399: 'her performance',
#  400: 'cmon seahawks',
#  401: 'patriots locker room attendant',
#  402: 'liam neeson commercial',
#  403: 'el estadio de la universidad de phoenix',
#  404: 'your commercial',
#  405: '70 patriots',
#  406: '1 hour',
#  407: 'a seahawk',
#  408: 'el halftime',
#  409: 'de katy perry',
#  410: 'superbowlxlix lets',
#  411: 'katyperrysuperbowl superbowl',
#  412: 'victoriassecret',
#  413: 'gohawks superbowlxlix',
#  414: 'funny superbowl',
#  415: 'superbowl promo',
#  416: 'tom bradys face',
#  417: 'richard shermans face',
#  418: 'real patriots',
#  419: 'your superbowl pick',
#  420: 'patriots football',
#  421: 'wow superbowl',
#  422: 'omg superbowl',
#  423: 'superbowl touchdown',
#  424: 'super bowl media day',
#  425: 'worst commercial',
#  426: 'pregame show',
#  427: 'sports fans',
#  428: 'superbowl advertisers',
#  429: 'nbc superbowl',
#  430: 'kim kardashian commercial',
#  431: 'great ad',
#  432: 'patriots champions',
#  433: '29 seconds',
#  434: 'super bowl loss',
#  435: 'smh superbowl',
#  436: 'about superbowl',
#  437: 'a beach ball',
#  438: '100 years',
#  439: 'lennykravitz superbowl',
#  440: 'budweiser superbowl',
#  441: 'underinflated balls',
#  442: 'some katyperry',
#  443: 'this game superbowl',
#  444: 'katy perrys halftime performance',
#  445: 'deflategate superbowl',
#  446: 'seahawks colors',
#  447: 'superbowlxlix gopats',
#  448: 'nfl championship',
#  449: 'nfl sb49',
#  450: 'nationwide superbowlcommercials',
#  451: 'el show de katyperry',
#  452: 'katy perrys sharks',
#  453: 'los new england',
#  454: 'superbowl fun',
#  455: 'patriots touchdown',
#  456: 'sports superbowl',
#  457: 'katy perrys outfit',
#  458: 'katyperry nfl',
#  459: 'superbowl dinner',
#  460: 'jeep commercial',
#  461: 'her superbowl performance',
#  462: 'katyperry firework',
#  463: 'a car commercial',
#  464: 'philadelphia eagles philadelphia eagles',
#  465: 'impresionante',
#  466: 'con el superbowl',
#  467: 'real life pacman',
#  468: 'all the superbowl commercials',
#  469: '15 yards',
#  470: 'pepsi superbowl',
#  471: 'actual superbowl',
#  472: 'patriots gopats',
#  473: 'what a superbowl',
#  474: 'this years superbowl commercials',
#  475: 'superbowl trophy',
#  476: '2824 patriots',
#  477: 'bmw commercial',
#  478: 'a deflated football',
#  479: 'superbowl nfl',
#  480: 'toenail fungus commercial',
#  481: 'commercial sb49',
#  482: 'cmon patriots',
#  483: 'real football',
#  484: 'your ass',
#  485: 'a superbowl ring',
#  486: 'my superbowlxlix prediction',
#  487: 'hahaha superbowl',
#  488: '24 seahawks',
#  489: 'fiatusa commercial',
#  490: 'superbowl seattle',
#  491: 'america superbowl',
#  492: 'superbowl coverage',
#  493: 'our patriots',
#  494: 'coa',
#  495: 'fully inflated balls',
#  496: 'a patriot',
#  497: 'puppy commercial',
#  498: 'a sporting event',
#  499: 'a great halftime show',
#  500: 'domestic violence commercial',
#  501: 'cocacola superbowl',
#  502: 'properly inflated balls',
#  503: 'your favorite superbowl ad',
#  504: 'seahawks seattleseahawks',
#  505: 'your favorite team',
#  506: 'a good game superbowlxlix',
#  507: 'katyperry roar',
#  508: 'no super bowl',
#  509: 'woooooooo',
#  510: 'presentacin de katyperry',
#  511: 'little blue pill',
#  512: 'superbowl xlix ads',
#  513: 'win superbowl',
#  514: 'katy perry song',
#  515: 'this superbowl thing',
#  516: '1414 superbowlxlix',
#  517: 'a question',
#  518: 'seahawks bandwagon',
#  519: 'funny superbowl commercials',
#  520: 'better superbowlxlix',
#  521: 'katyperrys superbowl performance',
#  522: 'ir 4th superbowl title',
#  523: 'missy elliott halftime show',
#  524: 'my favorite thing',
#  525: 'super bowl preview',
#  526: 'el ltimo cuarto',
#  527: 'superbowlxlix game',
#  528: 'katy perry fan',
#  529: 'a seahawks jersey',
#  530: 'interception seahawks',
#  531: '12 gohawks',
#  532: 'another td',
#  533: 'your superbowl menu',
#  534: 'superbowl trailer',
#  535: 'free superbowl',
#  536: 'superbowl seattleseahawks',
#  537: 'best superbowl games',
#  538: 'game patriots',
#  539: 'ir 4th superbowl',
#  540: 'seahawks player',
#  541: 'new terminator movie',
#  542: 'sb49 superbowl superbowl',
#  543: 'katy perrys dress',
#  544: 'right superbowl',
#  545: 'usa superbowl',
#  546: 'patriots time',
#  547: 'gooooooo',
#  548: 'lifesize pacman',
#  549: 'el superbowlxlix siempre',
#  550: 'entire superbowl',
#  551: 'nooooooooo',
#  552: 'a great superbowlxlix',
#  553: 'fucking superbowl',
#  554: 'last seconds',
#  555: 'brandbowl superbowl',
#  556: 'superbowlrally superbowl',
#  557: 'gooo patriots',
#  558: 'a good halftime show',
#  559: 'se sad commercials',
#  560: 'patriots newengland',
#  561: 'my ears',
#  562: 'con katy perry',
#  563: 'touchdownnnnnn',
#  564: 'perfect superbowl',
#  565: 'se players',
#  566: 'any other team',
#  567: 'goooo seahawks',
#  568: 'classy superbowl',
#  569: 'new england fans',
#  570: 'idina menzels national anthem',
#  571: 'd sb49',
#  572: 'a good one',
#  573: 'para los patriots',
#  574: 'katyperry show',
#  575: 'less than an hour',
#  576: 'listo para el superbowl',
#  577: 'all the depressing commercials',
#  578: 'yesssssssss',
#  579: 'this one superbowlxlix',
#  580: 'superbowl missyelliott',
#  581: 'those commercials',
#  582: 'godaddy commercial',
#  583: 'gisele bndchen',
#  584: 'patriots logo',
#  585: 'fourth super bowl win',
#  586: 'sb49 prediction',
#  587: 'superbowl halftime performance',
#  588: 'super bowl fines',
#  589: '2 years',
#  590: 'seahawks rally',
#  591: 'commercial superbowlcommercials',
#  592: 'an emotional roller coaster',
#  593: 'el ftbol americano',
#  594: 'pumpkin peach ale',
#  595: 'le super bowl',
#  596: 'what katy perry',
#  597: 'best superbowl party',
#  598: 'carnival cruises',
#  599: 'my favorite superbowl',
#  600: 'seahawks chris matthews',
#  601: 'katy superbowl',
#  602: 'patriots use',
#  603: 'no entiendo nada',
#  604: 'superbowl bet',
#  605: 'superbowl selfie',
#  606: 'superbowl score',
#  607: 'marshawn lynch superbowl',
#  608: 'my favorites',
#  609: 'superbowl parade',
#  610: 'ir superbowl victory',
#  611: 'min',
#  612: 'super bowl squares',
#  613: 'all the ads',
#  614: 'superbowlxlix solo',
#  615: 'bud light commercial',
#  616: 'tom sb49',
#  617: 'that commercial superbowlxlix',
#  618: 'super bowl teams',
#  619: 'superbowl hype',
#  620: 'all the superbowl ads',
#  621: 'el superbowlxlix los mejores comentaristas',
#  622: 'kimkardashian superbowl',
#  623: 'superbowi superbowlxlix',
#  624: 'ecuador sb49 allyouneedisecuador',
#  625: 'that superbowl ad',
#  626: 'incredible superbowl',
#  627: 'final del superbowl',
#  628: 'so many dad commercials',
#  629: 'lets goooo',
#  630: 'a colts',
#  631: 'katyperryhalftimeshow superbowl',
#  632: 'los aos',
#  633: 'another dad commercial',
#  634: 'superbowlxlix katyperrysuperbowl',
#  635: 'superbowl que',
#  636: '3 yards',
#  637: 'katyperry love',
#  638: '6 super bowls',
#  639: 'interesting superbowl',
#  640: 'el superbowlxlix estar',
#  641: 'insane superbowl',
#  642: 'yes touchdown',
#  643: 'intense superbowl',
#  644: 'ganaron los patriots',
#  645: 'good sb49',
#  646: '3 more hours',
#  647: 'bad superbowl',
#  648: 'top superbowl',
#  649: 'superbowlxlix patriotsnation',
#  650: 'superbowl kicks',
#  651: 'whole halftime show',
#  652: 'all the patriots fans',
#  653: 'all the seahawks fans',
#  654: 'superbowl players',
#  655: 'omg missy elliot',
#  656: 'fat',
#  657: 'deflate',
#  658: 'que superbowl',
#  659: 'm lynch',
#  660: '15 points',
#  661: 'a patriots hat',
#  662: 'superbowl national anthem',
#  663: 'epic superbowlxlix',
#  664: '2824 superbowlxlix',
#  665: '147 superbowl',
#  666: 'superbowl fever',
#  667: 'most depressing superbowl commercials',
#  668: 'superbowl seahawks patriots',
#  669: 'superbowl stage',
#  670: 'more superbowl ads',
#  671: 'best superbowl halftime',
#  672: 'victorias secret commercial',
#  673: '2 more days',
#  674: 'patriots score',
#  675: 'boom superbowlxlix',
#  676: 'patriots seahawks superbowl',
#  677: 'el comercial de',
#  678: 'seahawks play call',
#  679: 'seahawks pats',
#  680: 'those deflated balls',
#  681: 'a sb49',
#  682: '56 years old',
#  683: 'ir al superbowl',
#  684: 'this superbowlxlix halftime show',
#  685: 'nfl conference championships',
#  686: 'a pats',
#  687: 'good ad',
#  688: 'superbowl pregame show',
#  689: '21 patriots',
#  690: 'con seattle',
#  691: 'para katyperry',
#  692: 'para disfrutar el superbowl',
#  693: 'touchdown dance',
#  694: 'superbowlxlix contest',
#  695: 'damn superbowlxlix',
#  696: 'worst superbowl ad',
#  697: 'new superbowl',
#  698: 'missy elliott stole',
#  699: 'what a great superbowl',
#  700: 'commercial tho',
#  701: 'seahawks time',
#  702: 'missyyyyyyy',
#  703: 'missyelliott performance',
#  704: 'seattle win',
#  705: 'superbowl lmao',
#  706: 'sick superbowl',
#  707: 'seahawks patriots superbowl',
#  708: 'patriots superbowl champions',
#  709: 'seahawks nfcchampionship',
#  710: 'true patriots',
#  711: 'a seahawks victory',
#  712: '30 mins',
#  713: 'superbowl recap',
#  714: 'superbowl matchup',
#  715: 'anda',
#  716: 'superbowl gohawks',
#  717: 'new england patriots super bowl',
#  718: 'los seattle',
#  719: 'seahawks td',
#  720: 'another patriots',
#  721: 'yeah superbowl',
#  722: 'that missy elliot',
#  723: 'el superbowl por',
#  724: 'that seahawks',
#  725: 'super bowl brawl',
#  726: 'best patriots',
#  727: 'some seahawks',
#  728: 'espectacular',
#  729: 'an exciting superbowl',
#  730: 'some patriots',
#  731: 'its superbowl ad',
#  732: 'new england patriots champions',
#  733: 'superbowl xlviii',
#  734: 'yaaaasss',
#  735: 'whaaaaaat',
#  736: 'katyperry katy',
#  737: 'de seattle',
#  738: 'belichick press conference',
#  739: 'boring superbowl',
#  740: 'super bowl show',
#  741: 'lynch superbowlxlix',
#  742: 'katyperry bets',
#  743: '2015 super bowl champions',
#  744: '51 seahawks',
#  745: 'my superbowl experience',
#  746: '100 year old',
#  747: 'an amazing performance',
#  748: 'tmobile superbowl',
#  749: 'presenta',
#  750: 'awesome superbowlcommercials',
#  751: 'seahawks oc',
#  752: 'its the superbowl',
#  753: 'final superbowlxlix',
#  754: 'champions superbowl',
#  755: '3 year old',
#  756: 'more superbowlxlix',
#  757: 'lol gopatriots'}
